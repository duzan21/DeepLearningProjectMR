# %%
# %matplotlib inline
import os,random,sys
import numpy as np

import torch.nn as nn
import torch.nn.parallel
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.utils.data
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torch.nn.functional as F
from torchsummary import summary
device = torch.device("cuda") 

import matplotlib.pyplot as plt
import time
from glob import glob

# In Python 2, cPickle is the accelerated version of pickle, and a later addition to thestandard library.
# It was perfectly normal to import it with a fallback to pickle. In Python 3 the accelerated version has been integrated
# and there is simply no reason to use anything other than import pickle
import pickle

from google.colab import drive
drive.mount('/content/drive')
root = "/content/drive/My Drive/Deep Learning course 2020/Proj/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Dataset setup

# %%
# Load the dataset ...
Xd = pickle.load(open(root + "RML2016.10a_dict.pkl",'rb'), encoding="latin1")
snrs,mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1,0])
X = []  
lbl = []
for mod in mods:
    for snr in snrs:
        X.append(Xd[(mod,snr)])
        for i in range(Xd[(mod,snr)].shape[0]):  lbl.append((mod,snr))
X = np.vstack(X)

# X: (N, 2, 128). for each of the N=220,000 examples, there is a 128-long measurement of I/Q samples.
# mods: ['8PSK', 'AM-DSB', 'AM-SSB', 'BPSK', 'CPFSK', 'GFSK', 'PAM4', 'QAM16', 'QAM64', 'QPSK', 'WBFM']
# lbl: list of tuples, each of the pattern ('GFSK', -20)

# %%
# Partition the data
#  into training and test sets of the form we can train/test on 
#  while keeping SNR and Mod labels handy for each

np.random.seed(203142260 + 305773673)
n_examples = X.shape[0]  # 220,000
n_train = int(n_examples * 0.5)  # 110,000
train_idx = np.random.choice(range(0,n_examples), size=n_train, replace=False)
test_idx = list(set(range(0,n_examples))-set(train_idx))
X_train = X[train_idx]
X_test =  X[test_idx]

Y_train = np.array(list(map(lambda x: mods.index(lbl[x][0]), train_idx)))
Y_test = np.array(list(map(lambda x: mods.index(lbl[x][0]), test_idx)))

# %% [markdown]
# # Build the NN Model

# %%
#Pytorch
dr = 0.5 # dropout rate (%)
class CNN2(nn.Module):
    def __init__(self):
        super(CNN2, self).__init__()
        self.convPart = nn.Sequential(
            # input is batch x 1 x 2 x 128
            # (Reshape([1]+in_shp, input_shape=in_shp))  #  - Reshape [N,2,128] to [N,1,2,128] on input
            nn.Conv2d(1, 256, kernel_size=(1, 3), padding=(0, 2)),
            nn.ReLU(True),
            nn.Dropout(dr),
            # state size. batch x 256 x 2 x 130
            nn.Conv2d(in_channels=256, out_channels=80, kernel_size=(2, 3), padding=(0, 2)),
            nn.ReLU(True),
            nn.Dropout(dr),
            # state size. batch x 80 x 1 x 132
        )
        self.linPart = nn.Sequential(
            nn.Linear(80 * 132, 256),
            nn.ReLU(True),
            nn.Dropout(dr),
            # state size. batch x 256
            nn.Linear(256, len(mods)),
            nn.LogSoftmax(dim=1)
        )

    def forward(self, input):
        out = self.convPart(input)
        out = out.view(-1, 80 * 132)
        out = self.linPart(out)
        # out = F.softmax(out, dim=1)
        return out

# custom weights initialization #  to mean=0, stdev=0.2.
def weights_init(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)
    elif classname.find('Linear') != -1:
        nn.init.normal_(m.weight.data, 0.0, 0.02)
        nn.init.constant_(m.bias.data, 0)

# Create the generator and the Discriminator
net =  CNN2().to(device)
# Apply the weights_init function to randomly initialize all weights
net.apply(weights_init)

# Print the model                                    
print(net)

# model.add(Reshape([len(classes)]))
# model.compile(loss='categorical_crossentropy', optimizer='adam')
summary(net, (1, 2, 128))


lr = 0.0002
beta1 = 0.5
beta2 = 0.999

# criterion = nn.CrossEntropyLoss()
criterion = nn.NLLLoss()
# Setup Adam optimizers for both G and D
optimizer = optim.Adam(net.parameters(), lr=lr, betas=(beta1, beta2))
# Out:
# CNN2(
#   (convPart): Sequential(
#     (0): Conv2d(1, 256, kernel_size=(1, 3), stride=(1, 1), padding=(0, 2))
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Conv2d(256, 80, kernel_size=(2, 3), stride=(1, 1), padding=(0, 2))
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#   )
#   (linPart): Sequential(
#     (0): Linear(in_features=10560, out_features=256, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=256, out_features=11, bias=True)
#     (4): LogSoftmax()
#   )
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 256, 2, 130]           1,024
#               ReLU-2          [-1, 256, 2, 130]               0
#            Dropout-3          [-1, 256, 2, 130]               0
#             Conv2d-4           [-1, 80, 1, 132]         122,960
#               ReLU-5           [-1, 80, 1, 132]               0
#            Dropout-6           [-1, 80, 1, 132]               0
#             Linear-7                  [-1, 256]       2,703,616
#               ReLU-8                  [-1, 256]               0
#            Dropout-9                  [-1, 256]               0
#            Linear-10                   [-1, 11]           2,827
#        LogSoftmax-11                   [-1, 11]               0
# ================================================================
# Total params: 2,830,427
# Trainable params: 2,830,427
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 1.77
# Params size (MB): 10.80
# Estimated Total Size (MB): 12.57
# ----------------------------------------------------------------

# %% [markdown]
# # Train the Model

# %%
# Set up some params 
num_epochs = 100    #  Noam - they did 100
batch_size = 1100  # training batch size.  Noam - they did 1024
num_batches = len(X_train) // batch_size
epoch_size = batch_size * num_batches

# %%
def prepare_data_into_batches(data, labels, permute):
  # Prepare data
  if permute is True:
    perm = torch.randperm(len(data))  # Shuffles along the first axis. shape = (110000, 2, 128) just like X_train
  else:
    perm = np.arange(len(data))

  n_batches = len(data) // batch_size
  tot_size = n_batches * batch_size
  
  shuffled = data[perm]
  shuffled = shuffled[:tot_size]        # Cutting off the last part that is smaller than one batch.  shape = (tot_size, 2, 128) just like X_train
  prepared = shuffled.reshape(n_batches, -1, 2, 128)  # Get into a shape that each element is a batch. shape = (107, batch_size, 2, 128)
  prepared = np.expand_dims(prepared, axis=2)           # Add a space for num_channels (it's 1 in our case). shape = (107, batch_size, 1, 2, 128)

  labels = labels[perm]
  labels = labels[:tot_size]
  labels = labels.reshape(n_batches, -1)
  return prepared, labels
  
def get_batch_results(batch):
  batchData = torch.from_numpy(batch[0]).to(device)
  batchLabels = torch.from_numpy(batch[1]).to(device)
  
  output = net(batchData)
  _, pred = torch.max(output.detach(), dim=1)
  correct = torch.sum(pred.eq(batchLabels)).cpu().numpy()

  return output, batchLabels, correct

  
def save_network(epoch):
  path = f'{root}saved models/epoch {epoch+1}.pt'
  torch.save(netD.state_dict(), path)

# %%
trainLoss = np.zeros(num_epochs)
testLoss = np.zeros(num_epochs)

startEpoch = 100
loadPath = f'{root}saved models/epoch {100}.pt'
filename = glob(loadPath)[0]
net.load_state_dict(torch.load(filename))

for epoch in range(num_epochs):
  totEpoch = epoch + startEpoch
  print(f'epoch: {totEpoch + 1}/{num_epochs + startEpoch}, ', end='')
  start = time.time()

  trainData, trainLables = prepare_data_into_batches(X_train, Y_train, permute=True)
  testData, testLables = prepare_data_into_batches(X_test, Y_test, permute=True)
  
  net.train()
  correctTrain = 0
  trainEpochloss = 0
  for i, batch in enumerate(zip(trainData, trainLables)):
    net.zero_grad()

    output, batchLabels, correct = get_batch_results(batch)
    loss = criterion(output, batchLabels)
    loss.backward()
    optimizer.step()

    correctTrain += correct
    trainEpochloss += loss

  net.eval()
  correctTest = 0
  testEpochloss = 0
  with torch.no_grad():
    for i, batch in enumerate(zip(testData, testLables)):
      output, batchLabels, correct = get_batch_results(batch)
      correctTest += correct
      testEpochloss += criterion(output, batchLabels)

  trainAcc = correctTrain / epoch_size * 100
  testAcc = correctTest / epoch_size * 100
  trainLoss[epoch] = trainEpochloss / num_batches
  testLoss[epoch] = testEpochloss / num_batches
  print(f'train loss: {trainLoss[epoch]:.2f}, test loss: {testLoss[epoch]:.2f}, train accuracy: {trainAcc:.2f}%, test accuracy: {testAcc:.2f}%, elapsed time: {time.time() - start:.0f}s')
  torch.save(net.state_dict(), f'{root}saved models/epoch {totEpoch+1}.pt')
# Out:
# epoch: 101/200, train loss: 1.27, test loss: 1.26, train accuracy: 51.22%, test accuracy: 51.00%, elapsed time: 27s
# epoch: 102/200, train loss: 1.27, test loss: 1.26, train accuracy: 51.35%, test accuracy: 51.48%, elapsed time: 27s
# epoch: 103/200, train loss: 1.27, test loss: 1.26, train accuracy: 51.44%, test accuracy: 51.48%, elapsed time: 27s
# epoch: 104/200, train loss: 1.27, test loss: 1.26, train accuracy: 51.39%, test accuracy: 50.66%, elapsed time: 27s
# epoch: 105/200, train loss: 1.26, test loss: 1.26, train accuracy: 51.48%, test accuracy: 51.37%, elapsed time: 27s
# epoch: 106/200, train loss: 1.26, test loss: 1.26, train accuracy: 51.59%, test accuracy: 51.20%, elapsed time: 27s
# epoch: 107/200, train loss: 1.26, test loss: 1.26, train accuracy: 51.67%, test accuracy: 51.04%, elapsed time: 27s
# epoch: 108/200, train loss: 1.26, test loss: 1.27, train accuracy: 51.57%, test accuracy: 50.78%, elapsed time: 27s
# epoch: 109/200, train loss: 1.26, test loss: 1.26, train accuracy: 51.74%, test accuracy: 51.61%, elapsed time: 27s
# epoch: 110/200, train loss: 1.26, test loss: 1.27, train accuracy: 51.68%, test accuracy: 51.50%, elapsed time: 27s
# epoch: 111/200, train loss: 1.26, test loss: 1.25, train accuracy: 51.84%, test accuracy: 51.42%, elapsed time: 27s
# epoch: 112/200, train loss: 1.26, test loss: 1.26, train accuracy: 51.85%, test accuracy: 51.72%, elapsed time: 27s
# epoch: 113/200, train loss: 1.25, test loss: 1.27, train accuracy: 51.98%, test accuracy: 51.14%, elapsed time: 27s
# epoch: 114/200, train loss: 1.25, test loss: 1.26, train accuracy: 51.94%, test accuracy: 51.41%, elapsed time: 27s
# epoch: 115/200, train loss: 1.25, test loss: 1.27, train accuracy: 52.04%, test accuracy: 51.17%, elapsed time: 27s
# epoch: 116/200, train loss: 1.25, test loss: 1.27, train accuracy: 51.91%, test accuracy: 51.35%, elapsed time: 27s
# epoch: 117/200, train loss: 1.25, test loss: 1.27, train accuracy: 52.11%, test accuracy: 51.50%, elapsed time: 27s
# epoch: 118/200, train loss: 1.25, test loss: 1.26, train accuracy: 52.19%, test accuracy: 51.56%, elapsed time: 27s
# epoch: 119/200, train loss: 1.25, test loss: 1.26, train accuracy: 52.22%, test accuracy: 51.46%, elapsed time: 27s
# epoch: 120/200, train loss: 1.24, test loss: 1.25, train accuracy: 52.39%, test accuracy: 51.80%, elapsed time: 27s
# epoch: 121/200, train loss: 1.24, test loss: 1.27, train accuracy: 52.34%, test accuracy: 51.39%, elapsed time: 27s
# epoch: 122/200, train loss: 1.24, test loss: 1.25, train accuracy: 52.53%, test accuracy: 51.60%, elapsed time: 27s
# epoch: 123/200, train loss: 1.24, test loss: 1.26, train accuracy: 52.50%, test accuracy: 51.83%, elapsed time: 27s
# epoch: 124/200, train loss: 1.24, test loss: 1.26, train accuracy: 52.54%, test accuracy: 51.33%, elapsed time: 27s
# epoch: 125/200, train loss: 1.24, test loss: 1.26, train accuracy: 52.71%, test accuracy: 51.69%, elapsed time: 27s
# epoch: 126/200, train loss: 1.24, test loss: 1.25, train accuracy: 52.56%, test accuracy: 51.79%, elapsed time: 27s
# epoch: 127/200, train loss: 1.24, test loss: 1.25, train accuracy: 52.69%, test accuracy: 51.80%, elapsed time: 27s
# epoch: 128/200, train loss: 1.23, test loss: 1.25, train accuracy: 52.74%, test accuracy: 51.41%, elapsed time: 27s
# epoch: 129/200, train loss: 1.23, test loss: 1.25, train accuracy: 52.69%, test accuracy: 52.10%, elapsed time: 27s
# epoch: 130/200, train loss: 1.23, test loss: 1.27, train accuracy: 52.79%, test accuracy: 51.70%, elapsed time: 27s
# epoch: 131/200, train loss: 1.23, test loss: 1.25, train accuracy: 53.05%, test accuracy: 51.96%, elapsed time: 27s
# epoch: 132/200, train loss: 1.23, test loss: 1.25, train accuracy: 52.77%, test accuracy: 51.95%, elapsed time: 27s
# epoch: 133/200, train loss: 1.23, test loss: 1.27, train accuracy: 53.09%, test accuracy: 51.40%, elapsed time: 27s
# epoch: 134/200, train loss: 1.23, test loss: 1.26, train accuracy: 53.20%, test accuracy: 51.52%, elapsed time: 27s
# epoch: 135/200, train loss: 1.22, test loss: 1.25, train accuracy: 53.10%, test accuracy: 51.66%, elapsed time: 27s
# epoch: 136/200, train loss: 1.22, test loss: 1.25, train accuracy: 53.08%, test accuracy: 51.69%, elapsed time: 27s
# epoch: 137/200, train loss: 1.22, test loss: 1.25, train accuracy: 53.08%, test accuracy: 51.84%, elapsed time: 27s
# epoch: 138/200, train loss: 1.22, test loss: 1.26, train accuracy: 53.45%, test accuracy: 52.08%, elapsed time: 27s
# epoch: 139/200, train loss: 1.22, test loss: 1.25, train accuracy: 53.24%, test accuracy: 52.04%, elapsed time: 27s
# epoch: 140/200, train loss: 1.22, test loss: 1.26, train accuracy: 53.31%, test accuracy: 51.82%, elapsed time: 27s
# epoch: 141/200, train loss: 1.22, test loss: 1.25, train accuracy: 53.38%, test accuracy: 52.07%, elapsed time: 27s
# epoch: 142/200, train loss: 1.22, test loss: 1.26, train accuracy: 53.35%, test accuracy: 52.12%, elapsed time: 27s
# epoch: 143/200, train loss: 1.21, test loss: 1.25, train accuracy: 53.66%, test accuracy: 52.32%, elapsed time: 27s
# epoch: 144/200, train loss: 1.21, test loss: 1.25, train accuracy: 53.74%, test accuracy: 52.05%, elapsed time: 27s
# epoch: 145/200, train loss: 1.21, test loss: 1.25, train accuracy: 53.58%, test accuracy: 52.20%, elapsed time: 27s
# epoch: 146/200, train loss: 1.21, test loss: 1.25, train accuracy: 53.80%, test accuracy: 51.95%, elapsed time: 27s
# epoch: 147/200, train loss: 1.21, test loss: 1.25, train accuracy: 53.80%, test accuracy: 52.21%, elapsed time: 27s
# epoch: 148/200, train loss: 1.21, test loss: 1.25, train accuracy: 53.97%, test accuracy: 52.34%, elapsed time: 27s
# epoch: 149/200, train loss: 1.20, test loss: 1.26, train accuracy: 53.88%, test accuracy: 52.14%, elapsed time: 27s
# epoch: 150/200, train loss: 1.20, test loss: 1.25, train accuracy: 53.98%, test accuracy: 52.26%, elapsed time: 27s
# epoch: 151/200, train loss: 1.20, test loss: 1.25, train accuracy: 54.00%, test accuracy: 52.51%, elapsed time: 27s
# epoch: 152/200, train loss: 1.20, test loss: 1.27, train accuracy: 54.05%, test accuracy: 51.69%, elapsed time: 27s
# epoch: 153/200, train loss: 1.20, test loss: 1.25, train accuracy: 54.12%, test accuracy: 52.37%, elapsed time: 27s
# epoch: 154/200, train loss: 1.20, test loss: 1.25, train accuracy: 54.36%, test accuracy: 52.53%, elapsed time: 27s
# epoch: 155/200, train loss: 1.20, test loss: 1.25, train accuracy: 54.35%, test accuracy: 52.53%, elapsed time: 27s
# epoch: 156/200, train loss: 1.20, test loss: 1.25, train accuracy: 54.39%, test accuracy: 52.47%, elapsed time: 27s
# epoch: 157/200, train loss: 1.19, test loss: 1.25, train accuracy: 54.37%, test accuracy: 52.22%, elapsed time: 27s
# epoch: 158/200, train loss: 1.19, test loss: 1.25, train accuracy: 54.51%, test accuracy: 52.45%, elapsed time: 27s
# epoch: 159/200, train loss: 1.19, test loss: 1.25, train accuracy: 54.54%, test accuracy: 52.35%, elapsed time: 27s
# epoch: 160/200, train loss: 1.19, test loss: 1.25, train accuracy: 54.60%, test accuracy: 52.29%, elapsed time: 27s
# epoch: 161/200, train loss: 1.19, test loss: 1.25, train accuracy: 54.49%, test accuracy: 52.45%, elapsed time: 27s
# epoch: 162/200, train loss: 1.18, test loss: 1.25, train accuracy: 54.55%, test accuracy: 52.66%, elapsed time: 27s
# epoch: 163/200, train loss: 1.19, test loss: 1.24, train accuracy: 54.68%, test accuracy: 52.31%, elapsed time: 27s
# epoch: 164/200, train loss: 1.18, test loss: 1.24, train accuracy: 54.69%, test accuracy: 52.28%, elapsed time: 27s
# epoch: 165/200, train loss: 1.18, test loss: 1.24, train accuracy: 54.66%, test accuracy: 52.58%, elapsed time: 27s
# epoch: 166/200, train loss: 1.18, test loss: 1.24, train accuracy: 54.66%, test accuracy: 52.63%, elapsed time: 27s
# epoch: 167/200, train loss: 1.18, test loss: 1.25, train accuracy: 54.79%, test accuracy: 51.95%, elapsed time: 27s
# epoch: 168/200, train loss: 1.18, test loss: 1.24, train accuracy: 55.00%, test accuracy: 52.61%, elapsed time: 27s
# epoch: 169/200, train loss: 1.18, test loss: 1.25, train accuracy: 54.93%, test accuracy: 52.62%, elapsed time: 27s
# epoch: 170/200, train loss: 1.18, test loss: 1.24, train accuracy: 55.01%, test accuracy: 52.41%, elapsed time: 27s
# epoch: 171/200, train loss: 1.17, test loss: 1.24, train accuracy: 55.04%, test accuracy: 52.60%, elapsed time: 27s
# epoch: 172/200, train loss: 1.17, test loss: 1.25, train accuracy: 55.11%, test accuracy: 52.51%, elapsed time: 27s
# epoch: 173/200, train loss: 1.17, test loss: 1.25, train accuracy: 55.05%, test accuracy: 52.35%, elapsed time: 27s
# epoch: 174/200, train loss: 1.17, test loss: 1.24, train accuracy: 55.08%, test accuracy: 52.68%, elapsed time: 27s
# epoch: 175/200, train loss: 1.17, test loss: 1.24, train accuracy: 55.29%, test accuracy: 52.42%, elapsed time: 27s
# epoch: 176/200, train loss: 1.17, test loss: 1.25, train accuracy: 55.21%, test accuracy: 52.34%, elapsed time: 27s
# epoch: 177/200, train loss: 1.17, test loss: 1.24, train accuracy: 55.31%, test accuracy: 52.49%, elapsed time: 27s
# epoch: 178/200, train loss: 1.16, test loss: 1.25, train accuracy: 55.30%, test accuracy: 52.60%, elapsed time: 27s
# epoch: 179/200, train loss: 1.16, test loss: 1.24, train accuracy: 55.54%, test accuracy: 52.62%, elapsed time: 27s
# epoch: 180/200, train loss: 1.16, test loss: 1.25, train accuracy: 55.34%, test accuracy: 52.40%, elapsed time: 27s
# epoch: 181/200, train loss: 1.16, test loss: 1.24, train accuracy: 55.48%, test accuracy: 52.61%, elapsed time: 27s
# epoch: 182/200, train loss: 1.16, test loss: 1.24, train accuracy: 55.53%, test accuracy: 52.59%, elapsed time: 27s
# epoch: 183/200, train loss: 1.16, test loss: 1.25, train accuracy: 55.56%, test accuracy: 52.69%, elapsed time: 27s
# epoch: 184/200, train loss: 1.16, test loss: 1.24, train accuracy: 55.58%, test accuracy: 52.69%, elapsed time: 27s
# epoch: 185/200, train loss: 1.15, test loss: 1.25, train accuracy: 55.59%, test accuracy: 52.60%, elapsed time: 27s
# epoch: 186/200, train loss: 1.15, test loss: 1.25, train accuracy: 55.86%, test accuracy: 52.55%, elapsed time: 27s
# epoch: 187/200, train loss: 1.16, test loss: 1.25, train accuracy: 55.61%, test accuracy: 52.51%, elapsed time: 27s
# epoch: 188/200, train loss: 1.15, test loss: 1.25, train accuracy: 55.94%, test accuracy: 52.42%, elapsed time: 27s
# epoch: 189/200, train loss: 1.15, test loss: 1.25, train accuracy: 55.88%, test accuracy: 52.70%, elapsed time: 27s
# epoch: 190/200, train loss: 1.16, test loss: 1.24, train accuracy: 55.88%, test accuracy: 52.71%, elapsed time: 27s
# epoch: 191/200, train loss: 1.15, test loss: 1.24, train accuracy: 55.98%, test accuracy: 52.65%, elapsed time: 27s
# epoch: 192/200, train loss: 1.15, test loss: 1.24, train accuracy: 56.01%, test accuracy: 52.76%, elapsed time: 27s
# epoch: 193/200, train loss: 1.15, test loss: 1.24, train accuracy: 56.11%, test accuracy: 52.88%, elapsed time: 27s
# epoch: 194/200, train loss: 1.15, test loss: 1.25, train accuracy: 56.16%, test accuracy: 52.68%, elapsed time: 27s
# epoch: 195/200, train loss: 1.15, test loss: 1.24, train accuracy: 56.09%, test accuracy: 52.72%, elapsed time: 27s
# epoch: 196/200, train loss: 1.15, test loss: 1.25, train accuracy: 56.23%, test accuracy: 52.44%, elapsed time: 27s
# epoch: 197/200, train loss: 1.14, test loss: 1.24, train accuracy: 56.18%, test accuracy: 52.85%, elapsed time: 27s
# epoch: 198/200, train loss: 1.14, test loss: 1.25, train accuracy: 56.13%, test accuracy: 52.47%, elapsed time: 27s
# epoch: 199/200, train loss: 1.14, test loss: 1.25, train accuracy: 56.38%, test accuracy: 52.51%, elapsed time: 27s
# epoch: 200/200, train loss: 1.14, test loss: 1.24, train accuracy: 56.33%, test accuracy: 52.59%, elapsed time: 27s

# %% [markdown]
# # Evaluate and Plot Model Performance

# %%
# Show loss curves 
plt.figure()
plt.title('Training performance')
plt.plot(trainLoss, label='train loss')  # NOAM -  they had train loss + error - what does this mean?
plt.plot(testLoss, label='test loss')  # NOAM -  they had val_error is that different than the loss?
plt.legend()

# %%
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Blues, labels=[]):
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(labels))
    plt.xticks(tick_marks, labels, rotation=45)
    plt.yticks(tick_marks, labels)
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')


def get_conf_from_batch(out, labels):
  batch_conf = np.zeros([len(mods),len(mods)], dtype=int)
  for i in range(len(labels)):
    j = labels[i]              # true label
    k = int(np.argmax(out[i]))   # predicted label
    batch_conf[j,k] += 1
  return batch_conf


def prepare_batches(snr):
    snrIndices = np.argwhere(test_SNRs==snr)
    batches_per_snr = len(snrIndices) // batch_size
    last_batch_size = np.remainder(len(snrIndices), batch_size)
    
    snr_x = X_test[snrIndices]
    snr_y = Y_test[snrIndices]    

    signals, lables = prepare_data_into_batches(snr_x, snr_y, permute=False)
    
    x_last_batch = snr_x[-last_batch_size:]
    y_last_batch = snr_y[-last_batch_size:]

    x_last_batch = x_last_batch.reshape(-1, 2, 128)  
    x_last_batch = np.expand_dims(x_last_batch, axis=1)          
    # y_last_batch = y_last_batch.reshape(-1)
    
    return signals, lables, x_last_batch, y_last_batch

# %%
# 20 snrs, 100 batches per epoch - 5 batches per snr. but same amount of samples per snr isn't constant  (close: std ~ 41)
acc = {}
net.eval()
test_SNRs = np.array(list(map(lambda x: lbl[x][1], test_idx)))
for snr in snrs:
  print(f'SNR = {snr}dB: ', end='')

  conf = np.zeros([len(mods),len(mods)], dtype=int)
  confnorm = np.zeros([len(mods),len(mods)], dtype=float)
  signals, lables, x_last_batch, y_last_batch = prepare_batches(snr)

  for batch in zip(signals, lables):
    output, batchLabels,_ = get_batch_results(batch)
    conf += get_conf_from_batch(output.detach().cpu().numpy(), batchLabels)
  # last partial batch
  output, batchLabels,_ = get_batch_results((x_last_batch, y_last_batch))
  conf += get_conf_from_batch(output.detach().cpu().numpy(), batchLabels)

  for i in range(len(mods)):
    row_sum = np.sum(conf[i,:])
    if row_sum != 0:
      confnorm[i,:] = conf[i,:] / row_sum

  plt.figure()
  plot_confusion_matrix(confnorm, labels=mods, title=f'ConvNet Confusion Matrix (SNR={snr})')
  cor = np.sum(np.diag(confnorm))
  ncor = np.sum(confnorm) - cor
  acc[snr] = cor/(cor+ncor) * 100
  print (f'Overall Accuracy: {acc[snr]:.1f}%')
# Out:
# SNR = -20dB: Overall Accuracy: 9.7%
# SNR = -18dB: Overall Accuracy: 9.6%
# SNR = -16dB: Overall Accuracy: 9.3%
# SNR = -14dB: Overall Accuracy: 12.3%
# SNR = -12dB: Overall Accuracy: 15.0%
# SNR = -10dB: Overall Accuracy: 23.6%
# SNR = -8dB: Overall Accuracy: 35.4%
# SNR = -6dB: Overall Accuracy: 50.0%
# SNR = -4dB: Overall Accuracy: 59.7%
# SNR = -2dB: Overall Accuracy: 67.9%
# SNR = 0dB: Overall Accuracy: 74.1%
# SNR = 2dB: Overall Accuracy: 75.9%
# SNR = 4dB: Overall Accuracy: 75.1%
# SNR = 6dB: Overall Accuracy: 77.3%
# SNR = 8dB: Overall Accuracy: 75.6%
# SNR = 10dB: Overall Accuracy: 77.0%
# SNR = 12dB: Overall Accuracy: 76.6%
# SNR = 14dB: Overall Accuracy: 76.7%
# SNR = 16dB: Overall Accuracy: 74.8%
# SNR = 18dB: Overall Accuracy: 76.6%

# %%
# Plot accuracy curve
plt.figure()
plt.plot(snrs, list(map(lambda x: acc[x], snrs)))
plt.xlabel("Signal to Noise Ratio [dB]")
plt.ylabel("Classification Accuracy [%]")
plt.suptitle('CNN2 Classification Accuracy on RadioML 2016.10 Alpha')
# Out:
# Text(0.5, 0.98, 'CNN2 Classification Accuracy on RadioML 2016.10 Alpha')

# %%
# Save results to a pickle file for plotting later
fd = open(root + 'results_cnn2_d0.5.dat','wb')
pickle.dump( ("CNN2", 0.5, acc) , fd )

# %%
# Out:
# <All keys matched successfully>
